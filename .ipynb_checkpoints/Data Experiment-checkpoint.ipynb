# %%
import pandas as pd
import json
from pathlib import Path

# %%
json_file = 'data/samples.json'

# %%
# Open and load the JSON file into a dictionary
with open(json_file, 'r') as file:
    data = json.load(file)

# Print the data to verify contents
print(data)
# Out:
# {'names': ['940', '941', '943', '944', '945', '946', '947', '948', '949', '950', '952', '953', '954', '955', '956', '958', '959', '960', '961', '962', '963', '964', '966', '967', '968', '969', '970', '971', '972', '973', '974', '975', '978', '1233', '1234', '1235', '1236', '1237', '1238', '1242', '1243', '1246', '1253', '1254', '1258', '1259', '1260', '1264', '1265', '1273', '1275', '1276', '1277', '1278', '1279', '1280', '1281', '1282', '1283', '1284', '1285', '1286', '1287', '1288', '1289', '1290', '1291', '1292', '1293', '1294', '1295', '1296', '1297', '1298', '1308', '1309', '1310', '1374', '1415', '1439', '1441', '1443', '1486', '1487', '1489', '1490', '1491', '1494', '1495', '1497', '1499', '1500', '1501', '1502', '1503', '1504', '1505', '1506', '1507', '1508', '1510', '1511', '1512', '1513', '1514', '1515', '1516', '1517', '1518', '1519', '1521', '1524', '1526', '1527', '1530', '1531', '1532', '1533', '1534', '1535', '1536', '1537', '1539', '1540', '1541', '1542', '1543', '154
# ...

# %%
data.keys()
# Out:
# dict_keys(['names', 'metadata', 'samples'])

# %%
data['samples'][0].keys()
# Out:
# dict_keys(['id', 'otu_ids', 'sample_values', 'otu_labels'])

# %%
data['samples'][0]
# Out:
# {'id': '940',
#  'otu_ids': [1167,
#   2859,
#   482,
#   2264,
#   41,
#   1189,
#   352,
#   189,
#   2318,
#   1977,
#   3450,
#   874,
#   1959,
#   2191,
#   1950,
#   2077,
#   2275,
#   944,
#   2184,
#   2244,
#   2024,
#   2419,
#   2811,
#   165,
#   2782,
#   2247,
#   2011,
#   2396,
#   830,
#   2964,
#   1795,
#   2722,
#   307,
#   2178,
#   2908,
#   1193,
#   2167,
#   1208,
#   2039,
#   1274,
#   2739,
#   2737,
#   1314,
#   1962,
#   2186,
#   2335,
#   2936,
#   907,
#   833,
#   2483,
#   2475,
#   2491,
#   2291,
#   159,
#   2571,
#   2350,
#   2342,
#   2546,
#   725,
#   170,
#   1505,
#   513,
#   259,
#   1169,
#   258,
#   1232,
#   1497,
#   1498,
#   1503,
#   412,
#   2235,
#   1960,
#   1968,
#   121,
#   2065,
#   340,
#   2110,
#   2188,
#   357,
#   342],
#  'sample_values': [163,
#   126,
#   113,
#   78,
#   71,
#   51,
#   50,
#   47,
#   40,
#   40,
#   37,
#   36,
#   30,
#   28,
#   25,
#   23,
#   22,
#   19,
#   19,
#   14,
#   13,
# ...

# %%
json_path = 'data/Spotify.json'
df = pd.read_csv(json_path)
df
# Out:
#            artist_name                                         track_name  \
# 0          OneRepublic                                    I Ain't Worried
# 1         David Guetta                                    I'm Good (Blue)
# 2                  SZA                                          Kill Bill
# 3        Manuel Turizo                                         La Bachata
# 4            Sam Smith                          Unholy (feat. Kim Petras)
# 5               Eminem                                        Mockingbird
# 6       Arctic Monkeys                                   I Wanna Be Yours
# 7          Miley Cyrus                                            Flowers
# 8          Myke Towers                                               LALA
# 9         Taylor Swift                                        Blank Space
# 10            Bizarrap              Quevedo: Bzrp Music Sessions, Vol. 52
# 11      Olivia Rodrigo                                            vampire
# ...

# %%
json_path = 'data/Spotify.json'

# %%
df.to_json(json_path, orient='records', lines=True)

# %%
# Open and load the JSON file into a dictionary
with open(json_path, 'r') as file:
    data = json.load(file)

# Print the data to verify contents
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-b1a7ae91141d> in <module>
#       1 # Open and load the JSON file into a dictionary
#       2 with open(json_path, 'r') as file:
# ----> 3     data = json.load(file)
#       4
#       5 # Print the data to verify contents
#
# /opt/conda/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /opt/conda/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...
